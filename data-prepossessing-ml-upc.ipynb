# %% [markdown]
# <a href="https://www.kaggle.com/code/muchabean/data-prepossessing-ml-upc?scriptVersionId=168312065" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
file_path = '/kaggle/input/alpha-vantage-stock-symbols/combined_featured_stocks_daily_data.csv'

df = pd.read_csv(file_path)
df.head()
# Out:
#   Symbol   Timestamp     Open     High      Low    Close   Volume  \
# 0   AAPD  2022-08-09  25.2800  25.2800  25.0000  25.0202   1457.0
# 1   AAPD  2022-08-10  24.5999  24.7300  24.3631  24.3631  20270.0
# 2   AAPD  2022-08-11  24.2900  24.4821  24.1900  24.4821  15281.0
# 3   AAPD  2022-08-12  24.2900  24.3500  23.9602  23.9602  30432.0
# 4   AAPD  2022-08-15  24.0099  24.0099  23.7800  23.8056  36507.0
#
#    Price_Range  Daily_Return     SMA_5  ...     EMA_50  SMA_100    EMA_100  \
# 0       0.2800     -1.027690       NaN  ...  25.020200      NaN  25.020200
# 1       0.3669     -0.962606       NaN  ...  24.994431      NaN  25.007188
# 2       0.2921      0.790860       NaN  ...  24.974340      NaN  24.996790
# 3       0.3898     -1.357760       NaN  ...  24.934570      NaN  24.976264
# 4       0.2299     -0.850899  24.32624  ...  24.890296      NaN  24.953082
#
#    SMA_200    EMA_200  RSI      MACD  MACD_Signal  Volume_Change  \
# ...

# %% [markdown]
# ## BASIC INSPECTION OF THE DATASET

# %%
df.describe()
# Out:
# /opt/conda/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                 Open           High            Low          Close  \
# count  131573.000000  131573.000000  131573.000000  131573.000000
# mean       42.919245      43.418184      42.396599      42.919483
# std        68.146099      68.882749      67.359599      68.148559
# min         0.003300       0.003300       0.001900       0.001900
# 25%         7.960000       8.195000       7.690000       7.950000
# 50%        26.790000      27.120000      26.410000      26.780000
# 75%        48.430000      48.920000      47.950000      48.400000
# max       702.410000     705.070000     699.570000     702.100000
#
#              Volume    Price_Range   Daily_Return          SMA_5  \
# count  1.315730e+05  131573.000000  131573.000000  131373.000000
# mean   3.018133e+06       1.021585       0.015340      42.933481
# ...

# %% [markdown]
# ##
